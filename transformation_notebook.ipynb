# %%
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
wine_data = Path("Resources/WineData_raw.csv")
city_data = Path("Resources/CityData_raw.csv")

# %%
wine_df = pd.read_csv(wine_data)
wine_df.head(10)
# Out:
#    Unnamed: 0   country  points  price           province  \
# 0           0     Italy      87    NaN  Sicily & Sardinia
# 1           1  Portugal      87   15.0              Douro
# 2           2        US      87   14.0             Oregon
# 3           3        US      87   13.0           Michigan
# 4           4        US      87   65.0             Oregon
# 5           5     Spain      87   15.0     Northern Spain
# 6           6     Italy      87   16.0  Sicily & Sardinia
# 7           7    France      87   24.0             Alsace
# 8           8   Germany      87   12.0        Rheinhessen
# 9           9    France      87   27.0             Alsace
#
#                                                title             variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 7              Trimbach 2012 Gewurztraminer (Alsace)      Gewürztraminer
# 8  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...      Gewürztraminer
# 9  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks
# 5               Tandem
# 6      Terre di Giurfo
# 7             Trimbach
# 8          Heinz Eifel
# 9   Jean-Baptiste Adam

# %%
# Dropping null values from dataframe
wine_df.dropna(inplace=True)
#Deleting Unnamed column
del wine_df ["Unnamed: 0"]

# %%
wine_df.head()
# Out:
#     country  points  price        province  \
# 1  Portugal      87   15.0           Douro
# 2        US      87   14.0          Oregon
# 3        US      87   13.0        Michigan
# 4        US      87   65.0          Oregon
# 5     Spain      87   15.0  Northern Spain
#
#                                                title             variety  \
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#                 winery
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks
# 5               Tandem

# %%
# Define a function to remove special characters
def remove_special_characters(df):
    # Using regex to replace special characters with empty string
    df = df.replace(r'[^A-Za-z0-9 ]+', '', regex=True)
    return df

# Apply the function to the dataframe
cleaned_wine_df = remove_special_characters(wine_df)

print(cleaned_wine_df)
# Out:
#          country  points  price        province  \
# 1       Portugal      87   15.0           Douro
# 2             US      87   14.0          Oregon
# 3             US      87   13.0        Michigan
# 4             US      87   65.0          Oregon
# 5          Spain      87   15.0  Northern Spain
# ...          ...     ...    ...             ...
# 129966   Germany      90   28.0           Mosel
# 129967        US      90   75.0          Oregon
# 129968    France      90   30.0          Alsace
# 129969    France      90   32.0          Alsace
# 129970    France      90   21.0          Alsace
#
#                                                     title            variety  \
# 1             Quinta dos Avidagos 2011 Avidagos Red Douro     Portuguese Red
# 2             Rainstorm 2013 Pinot Gris Willamette Valley         Pinot Gris
# 3       St Julian 2013 Reserve Late Harvest Riesling L...           Riesling
# 4       Sweet Cheeks 2012 Vintners Reserve Wild Child ...         Pinot Noir
# 5       Tandem 2011 Ars In Vitro TempranilloMerlot Nav...  TempranilloMerlot
# ...                                                   ...                ...
# 129966  Dr H Thanisch Erben MllerBurggraef 2013 Braune...           Riesling
# 129967                    Citation 2004 Pinot Noir Oregon         Pinot Noir
# 129968   Domaine Gresser 2013 Kritt Gewurztraminer Alsace      Gewrztraminer
# 129969        Domaine Marcel Deiss 2012 Pinot Gris Alsace         Pinot Gris
# 129970  Domaine Schoffit 2012 Lieudit Harth Cuve Carol...      Gewrztraminer
#
#                                     winery
# 1                      Quinta dos Avidagos
# 2                                Rainstorm
# 3                                St Julian
# 4                             Sweet Cheeks
# 5                                   Tandem
# ...                                    ...
# 129966  Dr H Thanisch Erben MllerBurggraef
# 129967                            Citation
# 129968                     Domaine Gresser
# 129969                Domaine Marcel Deiss
# 129970                    Domaine Schoffit
#
# [120915 rows x 7 columns]

# %%
# Renaming "province" column to "region"
cleaned_wine_df = cleaned_wine_df.rename(columns={
    "province": "region",
    "variety": "category"})

# %%
cleaned_wine_df.head()
# Out:
#     country  points  price          region  \
# 1  Portugal      87   15.0           Douro
# 2        US      87   14.0          Oregon
# 3        US      87   13.0        Michigan
# 4        US      87   65.0          Oregon
# 5     Spain      87   15.0  Northern Spain
#
#                                                title           category  \
# 1        Quinta dos Avidagos 2011 Avidagos Red Douro     Portuguese Red
# 2        Rainstorm 2013 Pinot Gris Willamette Valley         Pinot Gris
# 3  St Julian 2013 Reserve Late Harvest Riesling L...           Riesling
# 4  Sweet Cheeks 2012 Vintners Reserve Wild Child ...         Pinot Noir
# 5  Tandem 2011 Ars In Vitro TempranilloMerlot Nav...  TempranilloMerlot
#
#                 winery
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3            St Julian
# 4         Sweet Cheeks
# 5               Tandem

# %%
# Create a unique regionID for each unique region, and a wineID for each wine title
cleaned_wine_df['regionID'] = cleaned_wine_df['region'].astype('category').cat.codes
cleaned_wine_df['wineID'] = cleaned_wine_df['title'].astype('category').cat.codes

# %%
cleaned_wine_df.head(30)
# Out:
#       country  points  price            region  \
# 1    Portugal      87   15.0             Douro
# 2          US      87   14.0            Oregon
# 3          US      87   13.0          Michigan
# 4          US      87   65.0            Oregon
# 5       Spain      87   15.0    Northern Spain
# 6       Italy      87   16.0  Sicily  Sardinia
# 7      France      87   24.0            Alsace
# 8     Germany      87   12.0       Rheinhessen
# 9      France      87   27.0            Alsace
# 10         US      87   19.0        California
# 11     France      87   30.0            Alsace
# 12         US      87   34.0        California
# 14         US      87   12.0        California
# 15    Germany      87   24.0             Mosel
# 16  Argentina      87   30.0             Other
# 17  Argentina      87   13.0  Mendoza Province
# 18      Spain      87   28.0    Northern Spain
# 19         US      87   32.0          Virginia
# 20         US      87   23.0          Virginia
# 21         US      87   20.0            Oregon
# 22      Italy      87   19.0  Sicily  Sardinia
# 23         US      87   22.0        California
# 24      Italy      87   35.0  Sicily  Sardinia
# 25         US      87   69.0        California
# 26      Italy      87   13.0  Sicily  Sardinia
# 27      Italy      87   10.0  Sicily  Sardinia
# 28      Italy      87   17.0  Sicily  Sardinia
# 29         US      86   16.0        California
# 33         US      86   50.0        California
# 34         US      86   20.0        California
#
#                                                 title            category  \
# 1         Quinta dos Avidagos 2011 Avidagos Red Douro      Portuguese Red
# 2         Rainstorm 2013 Pinot Gris Willamette Valley          Pinot Gris
# 3   St Julian 2013 Reserve Late Harvest Riesling L...            Riesling
# 4   Sweet Cheeks 2012 Vintners Reserve Wild Child ...          Pinot Noir
# 5   Tandem 2011 Ars In Vitro TempranilloMerlot Nav...   TempranilloMerlot
# 6      Terre di Giurfo 2013 Belsito Frappato Vittoria            Frappato
# 7                 Trimbach 2012 Gewurztraminer Alsace       Gewrztraminer
# 8    Heinz Eifel 2013 Shine Gewrztraminer Rheinhessen       Gewrztraminer
# 9   JeanBaptiste Adam 2012 Les Natures Pinot Gris ...          Pinot Gris
# 10  Kirkland Signature 2011 Mountain Cuve Cabernet...  Cabernet Sauvignon
# 11              Leon Beyer 2012 Gewurztraminer Alsace       Gewrztraminer
# 12  Louis M Martini 2012 Cabernet Sauvignon Alexan...  Cabernet Sauvignon
# 14             Mirassou 2012 Chardonnay Central Coast          Chardonnay
# 15           Richard Bcking 2013 Devon Riesling Mosel            Riesling
# 16           Felix Lavaque 2010 Felix Malbec Cafayate              Malbec
# 17  Gaucho Andino 2011 Winemaker Selection Malbec ...              Malbec
# 18  Pradorey 2010 Vendimia Seleccionada Finca Vald...   Tempranillo Blend
# 19                  Quivremont 2012 Meritage Virginia            Meritage
# 20         Quivremont 2012 Vin de Maison Red Virginia           Red Blend
# 21                     Acrobat 2013 Pinot Noir Oregon          Pinot Noir
# 22    Baglio di Pianetto 2007 Ficiligno White Sicilia         White Blend
# 23  Bianchi 2011 Signature Selection Merlot Paso R...              Merlot
# 24            Canicatt 2009 Aynat Nero dAvola Sicilia         Nero dAvola
# 25  Castello di Amorosa 2011 King Ridge Vineyard P...          Pinot Noir
# 26         Stemmari 2013 Dalila White Terre Siciliane         White Blend
# 27          Stemmari 2013 Nero dAvola Terre Siciliane         Nero dAvola
# 28  Terre di Giurfo 2011 Mascaria Barricato  Ceras...           Red Blend
# 29  Clarksburg Wine Company 2010 Chenin Blanc Clar...        Chenin Blanc
# 33  Envolve 2010 Puma Springs Vineyard Red Dry Cre...           Red Blend
# 34         Envolve 2011 Sauvignon Blanc Sonoma Valley     Sauvignon Blanc
#
#                      winery  regionID  wineID
# 1       Quinta dos Avidagos       108   82440
# 2                 Rainstorm       266   82837
# 3                 St Julian       216   93497
# 4              Sweet Cheeks       266   95364
# 5                    Tandem       260   96092
# 6           Terre di Giurfo       331   98064
# 7                  Trimbach        11  100756
# 8               Heinz Eifel       304   49561
# 9         JeanBaptiste Adam        11   53990
# 10       Kirkland Signature        51   57059
# 11               Leon Beyer        11   61426
# 12          Louis M Martini        51   63546
# 14                 Mirassou        51   70290
# 15           Richard Bcking       230   84509
# 16            Felix Lavaque       267   41064
# 17            Gaucho Andino       214   45489
# 18                 Pradorey       260   80229
# 19               Quivremont       395   82590
# 20               Quivremont       395   82591
# 21                  Acrobat       266     724
# 22       Baglio di Pianetto       331    6188
# 23                  Bianchi        51    8846
# 24                 Canicatt       331   15031
# 25      Castello di Amorosa        51   17714
# 26                 Stemmari       331   94143
# 27                 Stemmari       331   94145
# 28          Terre di Giurfo       331   98059
# 29  Clarksburg Wine Company        51   25964
# 33                  Envolve        51   39197
# 34                  Envolve        51   39199

# %%
cleaned_wine_df = cleaned_wine_df.rename(columns={
    "regionID": "region_id",
    "wineID": "wine_id",
    "points": "score"})

# %%
# Reorder the dataframe
wine_order = ['wine_id', 'title', 'category', 'winery', 'region', 'region_id', 'country', 'score', 'price']

ordered_wine_df = cleaned_wine_df[wine_order]

# %%
ordered_wine_df
# Out:
#         wine_id                                              title  \
# 1         82440        Quinta dos Avidagos 2011 Avidagos Red Douro
# 2         82837        Rainstorm 2013 Pinot Gris Willamette Valley
# 3         93497  St Julian 2013 Reserve Late Harvest Riesling L...
# 4         95364  Sweet Cheeks 2012 Vintners Reserve Wild Child ...
# 5         96092  Tandem 2011 Ars In Vitro TempranilloMerlot Nav...
# ...         ...                                                ...
# 129966    36491  Dr H Thanisch Erben MllerBurggraef 2013 Braune...
# 129967    25847                    Citation 2004 Pinot Noir Oregon
# 129968    33057   Domaine Gresser 2013 Kritt Gewurztraminer Alsace
# 129969    33498        Domaine Marcel Deiss 2012 Pinot Gris Alsace
# 129970    34037  Domaine Schoffit 2012 Lieudit Harth Cuve Carol...
#
#                  category                              winery          region  \
# 1          Portuguese Red                 Quinta dos Avidagos           Douro
# 2              Pinot Gris                           Rainstorm          Oregon
# 3                Riesling                           St Julian        Michigan
# 4              Pinot Noir                        Sweet Cheeks          Oregon
# 5       TempranilloMerlot                              Tandem  Northern Spain
# ...                   ...                                 ...             ...
# 129966           Riesling  Dr H Thanisch Erben MllerBurggraef           Mosel
# 129967         Pinot Noir                            Citation          Oregon
# 129968      Gewrztraminer                     Domaine Gresser          Alsace
# 129969         Pinot Gris                Domaine Marcel Deiss          Alsace
# 129970      Gewrztraminer                    Domaine Schoffit          Alsace
#
#         region_id   country  score  price
# 1             108  Portugal     87   15.0
# 2             266        US     87   14.0
# 3             216        US     87   13.0
# 4             266        US     87   65.0
# 5             260     Spain     87   15.0
# ...           ...       ...    ...    ...
# 129966        230   Germany     90   28.0
# 129967        266        US     90   75.0
# 129968         11    France     90   30.0
# 129969         11    France     90   32.0
# 129970         11    France     90   21.0
#
# [120915 rows x 9 columns]

# %%
# Checking the data types
ordered_wine_df.dtypes
# Out:
# wine_id        int32
# title         object
# category      object
# winery        object
# region        object
# region_id      int16
# country       object
# score          int64
# price        float64
# dtype: object

# %%
# Convert 'regionID', 'wineID and 'price' columns to int64 to match SQL ERD
ordered_wine_df['region_id'] = ordered_wine_df['region_id'].astype('int64')
ordered_wine_df['price'] = ordered_wine_df['price'].astype('int64')
ordered_wine_df['wine_id'] = ordered_wine_df['wine_id'].astype('int64')

# %%
ordered_wine_df.dtypes
# Out:
# wine_id       int64
# title        object
# category     object
# winery       object
# region       object
# region_id     int64
# country      object
# score         int64
# price         int64
# dtype: object

# %%
ordered_wine_df.head()
# Out:
#    wine_id                                              title  \
# 1    82440        Quinta dos Avidagos 2011 Avidagos Red Douro
# 2    82837        Rainstorm 2013 Pinot Gris Willamette Valley
# 3    93497  St Julian 2013 Reserve Late Harvest Riesling L...
# 4    95364  Sweet Cheeks 2012 Vintners Reserve Wild Child ...
# 5    96092  Tandem 2011 Ars In Vitro TempranilloMerlot Nav...
#
#             category               winery          region  region_id  \
# 1     Portuguese Red  Quinta dos Avidagos           Douro        108
# 2         Pinot Gris            Rainstorm          Oregon        266
# 3           Riesling            St Julian        Michigan        216
# 4         Pinot Noir         Sweet Cheeks          Oregon        266
# 5  TempranilloMerlot               Tandem  Northern Spain        260
#
#     country  score  price
# 1  Portugal     87     15
# 2        US     87     14
# 3        US     87     13
# 4        US     87     65
# 5     Spain     87     15

# %%
city_df = pd.read_csv(city_data)
city_df.head(10)
# Out:
#                City      Lat       Lng  Avg_Temp_2023  Total_Prcp_2023
# 0             Douro  44.3834  -78.1995       8.150000            889.5
# 1            Oregon  44.0001 -120.5014            NaN              NaN
# 2          Michigan  44.2503  -85.5003       8.718182            751.0
# 3            Alsace  48.5000    7.5000      12.983333            535.4
# 4        California  38.3004  -76.5074      15.381818            780.2
# 5             Mosel  50.7833   12.4667      10.633333            753.8
# 6  Mendoza Province -34.5000  -68.5000      16.658333            337.5
# 7          Virginia  37.5481  -77.4467      16.175000           1105.1
# 8        Beaujolais  29.7858  -90.7681      22.072727           1172.4
# 9          Bordeaux  44.8404   -0.5805      15.133333           1111.4

# %%
# Removing null values from dataframe
city_df.dropna(inplace=True)

# %%
# Renaming columns in the dataframe
city_df = city_df.rename(columns={
    "City": "region",
    "Lat": "lat",
    "Lng" : "lng",
    "Avg_Temp_2023": "temp",
    "Total_Prcp_2023": "prcp"})

# %%
city_df.head()
# Out:
#        region      lat      lng       temp   prcp
# 0       Douro  44.3834 -78.1995   8.150000  889.5
# 2    Michigan  44.2503 -85.5003   8.718182  751.0
# 3      Alsace  48.5000   7.5000  12.983333  535.4
# 4  California  38.3004 -76.5074  15.381818  780.2
# 5       Mosel  50.7833  12.4667  10.633333  753.8

# %%
city_df.dtypes
# Out:
# region     object
# lat       float64
# lng       float64
# temp      float64
# prcp      float64
# dtype: object

# %%
#Create a mapping of regionID to match region ID in our wine dataframe
region_to_regionID = dict(zip(cleaned_wine_df['region'], cleaned_wine_df['region_id']))

city_df['regionID'] = city_df['region'].map(region_to_regionID)

# %%
city_df.head()
# Out:
#        region      lat      lng       temp   prcp  regionID
# 0       Douro  44.3834 -78.1995   8.150000  889.5     108.0
# 2    Michigan  44.2503 -85.5003   8.718182  751.0     216.0
# 3      Alsace  48.5000   7.5000  12.983333  535.4      11.0
# 4  California  38.3004 -76.5074  15.381818  780.2      51.0
# 5       Mosel  50.7833  12.4667  10.633333  753.8     230.0

# %%
city_df = city_df.rename(columns={
    "regionID": "region_id"})

# %%
# Reorder dataframe columns
city_order = ['region_id', 'region', 'lat', 'lng', 'temp', 'prcp']

ordered_city_df = city_df[city_order]

# %%
ordered_city_df.head()
# Out:
#    region_id      region      lat      lng       temp   prcp
# 0      108.0       Douro  44.3834 -78.1995   8.150000  889.5
# 2      216.0    Michigan  44.2503 -85.5003   8.718182  751.0
# 3       11.0      Alsace  48.5000   7.5000  12.983333  535.4
# 4       51.0  California  38.3004 -76.5074  15.381818  780.2
# 5      230.0       Mosel  50.7833  12.4667  10.633333  753.8

# %%
# Dropping null values from dataframe
ordered_city_df.dropna(inplace=True)
# Out:
# C:\Users\Rob\AppData\Local\Temp\ipykernel_24632\1204144997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ordered_city_df.dropna(inplace=True)

# %%
ordered_city_df.dtypes
# Out:
# region_id    float64
# region        object
# lat          float64
# lng          float64
# temp         float64
# prcp         float64
# dtype: object

# %%
# Convert 'regionID', 'wineID and 'price' columns to int64 to match SQL ERD
ordered_city_df['region_id'] = ordered_city_df['region_id'].astype('int64')
# Out:
# C:\Users\Rob\AppData\Local\Temp\ipykernel_24632\4226223305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ordered_city_df['region_id'] = ordered_city_df['region_id'].astype('int64')

# %%
ordered_city_df.dtypes
# Out:
# region_id      int64
# region        object
# lat          float64
# lng          float64
# temp         float64
# prcp         float64
# dtype: object

# %%
# Export cleaned data to Resources folder for further analysis
ordered_city_df.to_csv('Resources/CityData_cleaned.csv', index=False)
ordered_wine_df.to_csv('Resources/WineData_cleaned.csv', index=False)

# %%
ordered_wine_df.head()
# Out:
#    wine_id                                              title  \
# 1    82440        Quinta dos Avidagos 2011 Avidagos Red Douro
# 2    82837        Rainstorm 2013 Pinot Gris Willamette Valley
# 3    93497  St Julian 2013 Reserve Late Harvest Riesling L...
# 4    95364  Sweet Cheeks 2012 Vintners Reserve Wild Child ...
# 5    96092  Tandem 2011 Ars In Vitro TempranilloMerlot Nav...
#
#             category               winery          region  region_id  \
# 1     Portuguese Red  Quinta dos Avidagos           Douro        108
# 2         Pinot Gris            Rainstorm          Oregon        266
# 3           Riesling            St Julian        Michigan        216
# 4         Pinot Noir         Sweet Cheeks          Oregon        266
# 5  TempranilloMerlot               Tandem  Northern Spain        260
#
#     country  score  price
# 1  Portugal     87     15
# 2        US     87     14
# 3        US     87     13
# 4        US     87     65
# 5     Spain     87     15

# %%
price_chart = {
    'wine_id': ordered_wine_df['wine_id'],
    'score': ordered_wine_df['score'],
    'price': ordered_wine_df['price'],
    'region_id': ordered_wine_df['region_id']}

price_df = pd.DataFrame(price_chart)

# %%
price_df.head()
# Out:
#    wine_id  score  price  region_id
# 1    82440     87     15        108
# 2    82837     87     14        266
# 3    93497     87     13        216
# 4    95364     87     65        266
# 5    96092     87     15        260

# %%
price_order = ['wine_id', 'region_id', 'price', 'score']

ordered_price_df = price_df[price_order]

# %%
ordered_wine_df.head()
# Out:
#    wine_id                                              title  \
# 1    82440        Quinta dos Avidagos 2011 Avidagos Red Douro
# 2    82837        Rainstorm 2013 Pinot Gris Willamette Valley
# 3    93497  St Julian 2013 Reserve Late Harvest Riesling L...
# 4    95364  Sweet Cheeks 2012 Vintners Reserve Wild Child ...
# 5    96092  Tandem 2011 Ars In Vitro TempranilloMerlot Nav...
#
#             category               winery          region  region_id  \
# 1     Portuguese Red  Quinta dos Avidagos           Douro        108
# 2         Pinot Gris            Rainstorm          Oregon        266
# 3           Riesling            St Julian        Michigan        216
# 4         Pinot Noir         Sweet Cheeks          Oregon        266
# 5  TempranilloMerlot               Tandem  Northern Spain        260
#
#     country  score  price
# 1  Portugal     87     15
# 2        US     87     14
# 3        US     87     13
# 4        US     87     65
# 5     Spain     87     15

# %%
#Deleting Unnamed column
del ordered_wine_df ["country"]

# %%
del ordered_wine_df ["score"]

# %%
del ordered_wine_df ["price"]

# %%
del ordered_wine_df ["region"]

# %%
ordered_wine_df.head()
# Out:
#    wine_id                                              title  \
# 1    82440        Quinta dos Avidagos 2011 Avidagos Red Douro
# 2    82837        Rainstorm 2013 Pinot Gris Willamette Valley
# 3    93497  St Julian 2013 Reserve Late Harvest Riesling L...
# 4    95364  Sweet Cheeks 2012 Vintners Reserve Wild Child ...
# 5    96092  Tandem 2011 Ars In Vitro TempranilloMerlot Nav...
#
#             category               winery  region_id
# 1     Portuguese Red  Quinta dos Avidagos        108
# 2         Pinot Gris            Rainstorm        266
# 3           Riesling            St Julian        216
# 4         Pinot Noir         Sweet Cheeks        266
# 5  TempranilloMerlot               Tandem        260

# %%
ordered_wine_df.shape
# Out:
# (120915, 5)

# %%
wine_df_dropped = ordered_wine_df.drop_duplicates(subset=['wine_id',])

# %%
wine_df_dropped.shape
# Out:
# (110575, 5)

# %%
ordered_price_df.to_csv('Resources/PriceData_cleaned.csv', index=False)

# %%
ordered_city_df.head()
# Out:
#    region_id      region      lat      lng       temp   prcp
# 0        108       Douro  44.3834 -78.1995   8.150000  889.5
# 2        216    Michigan  44.2503 -85.5003   8.718182  751.0
# 3         11      Alsace  48.5000   7.5000  12.983333  535.4
# 4         51  California  38.3004 -76.5074  15.381818  780.2
# 5        230       Mosel  50.7833  12.4667  10.633333  753.8

# %%
ordered_price_df.head()
# Out:
#    wine_id  region_id  price  score
# 1    82440        108     15     87
# 2    82837        266     14     87
# 3    93497        216     13     87
# 4    95364        266     65     87
# 5    96092        260     15     87

# %%
# Export cleaned data to Resources folder for further analysis
ordered_city_df.to_csv('Resources/CityData_sql.csv', index=False)
wine_df_dropped.to_csv('Resources/WineData_sql_dropped.csv', index=False)
ordered_price_df.to_csv('Resources/PriceData_sql.csv', index=False)
